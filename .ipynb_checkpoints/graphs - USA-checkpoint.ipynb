# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

import matplotlib.ticker as mtick

import glob

# %%
from census import Census
from us import states

# %%
states.lookup('DC')
# Out:
# <State:District of Columbia>

# %%
df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv', \
                 parse_dates=True)

# %%
df = df[df['Country/Region'] == 'US']

# %%
df = df[df['Province/State'] != 'Diamond Princess']
df = df[df['Province/State'] != 'Grand Princess']

# %%
df = df.groupby('Province/State').sum()

# %%
df
# Out:
#                            Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Province/State
# Adams, IN              39.8522  -77.2865        0        0        0        0
# Alabama                32.3182  -86.9023        0        0        0        0
# Alachua, FL            29.7938  -82.4944        0        0        0        0
# Alameda County, CA     37.6017 -121.7195        0        0        0        0
# Alaska                 61.3707 -152.4044        0        0        0        0
# ...                        ...       ...      ...      ...      ...      ...
# Williamson County, TN  35.9179  -86.8622        0        0        0        0
# Wisconsin              44.2685  -89.6165        0        0        0        0
# Worcester, MA          42.4097  -71.8571        0        0        0        0
# Wyoming                42.7560 -107.3025        0        0        0        0
# Yolo County, CA        38.7646 -121.9018        0        0        0        0
#
#                        1/26/20  1/27/20  1/28/20  1/29/20  ...  3/11/20  \
# Province/State                                             ...
# Adams, IN                    0        0        0        0  ...        0
# Alabama                      0        0        0        0  ...        0
# Alachua, FL                  0        0        0        0  ...        0
# Alameda County, CA           0        0        0        0  ...        0
# Alaska                       0        0        0        0  ...        0
# ...                        ...      ...      ...      ...  ...      ...
# Williamson County, TN        0        0        0        0  ...        0
# Wisconsin                    0        0        0        0  ...        6
# Worcester, MA                0        0        0        0  ...        0
# Wyoming                      0        0        0        0  ...        0
# Yolo County, CA              0        0        0        0  ...        0
#
#                        3/12/20  3/13/20  3/14/20  3/15/20  3/16/20  3/17/20  \
# Province/State
# Adams, IN                    0        0        0        0        0        0
# Alabama                      0        5        6       12       29       39
# Alachua, FL                  0        0        0        0        0        0
# Alameda County, CA           0        0        0        0        0        0
# Alaska                       0        1        1        1        1        3
# ...                        ...      ...      ...      ...      ...      ...
# Williamson County, TN        0        0        0        0        0        0
# Wisconsin                    8       19       27       32       47       72
# Worcester, MA                0        0        0        0        0        0
# Wyoming                      1        1        2        3        3       11
# Yolo County, CA              0        0        0        0        0        0
#
#                        3/18/20  3/19/20  3/20/20
# Province/State
# Adams, IN                    0        0        0
# Alabama                     46       78       83
# Alachua, FL                  0        0        0
# Alameda County, CA           0        0        0
# Alaska                       6        9       12
# ...                        ...      ...      ...
# Williamson County, TN        0        0        0
# Wisconsin                   92      159      207
# Worcester, MA                0        0        0
# Wyoming                     15       18       19
# Yolo County, CA              0        0        0
#
# [245 rows x 61 columns]

# %%
df = df.T
df = df.drop('Lat')
df = df.drop('Long')

# %%
df.columns
# Out:
# Index(['Adams, IN', 'Alabama', 'Alachua, FL', 'Alameda County, CA', 'Alaska',
#        'Anoka, MN', 'Arapahoe, CO', 'Arizona', 'Arkansas', 'Arlington, VA',
#        ...
#        'Wayne, MI', 'Weber, UT', 'West Virginia', 'Westchester County, NY',
#        'Whatcom, WA', 'Williamson County, TN', 'Wisconsin', 'Worcester, MA',
#        'Wyoming', 'Yolo County, CA'],
#       dtype='object', name='Province/State', length=245)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index.name = 'Date'

# %%
today = df.iloc[-1]

# %%
condition = today[(today > 250)].index

# %%
print(condition)
# Out:
# Index(['California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Illinois', 'Louisiana', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Nevada', 'New Jersey', 'New York', 'North Carolina',
#        'Ohio', 'Oregon', 'Pennsylvania', 'South Carolina', 'Tennessee',
#        'Texas', 'Virginia', 'Washington', 'Wisconsin'],
#       dtype='object', name='Province/State')

# %%
min_case_num = 250
title_name = "USA"

# %%
data = {}
data_original = {}

for s in condition:
    state = df[s]
    state0 = state[state > min_case_num]
    
    state0 = state0.reset_index()
    state0 = state0[s]
    
    data[s] = state0
    data_original[s] = df[s]

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
today.sum()
# Out:
# 19028.0

# %%
for c in data.keys():
    if len(data[c]) > 1:
        growth_rate = data[c].tail(5).pct_change().mean()
        num_cases = data[c].iloc[-1]
        projected_num_cases = int(num_cases*(1+growth_rate)**7)

        print(c)
        print('% growth rate:', round(growth_rate * 100, 2),'%')
        print('# Infected (today):', int(num_cases))
        print('# Infected (projected in 7 days):', int(projected_num_cases))
        print('--')
# Out:
# California
# % growth rate: 20.83 %
# # Infected (today): 1177
# # Infected (projected in 7 days): 4424
# --
# Colorado
# % growth rate: 24.15 %
# # Infected (today): 363
# # Infected (projected in 7 days): 1649
# --
# Connecticut
# % growth rate: 22.01 %
# # Infected (today): 194
# # Infected (projected in 7 days): 780
# --
# Florida
# % growth rate: 38.13 %
# # Infected (today): 563
# # Infected (projected in 7 days): 5402
# --
# Georgia
# % growth rate: 36.88 %
# # Infected (today): 420
# # Infected (projected in 7 days): 3781
# --
# Illinois
# % growth rate: 63.27 %
# # Infected (today): 585
# # Infected (projected in 7 days): 18091
# --
# Louisiana
# % growth rate: 41.25 %
# # Infected (today): 538
# # Infected (projected in 7 days): 6036
# --
# Maryland
# % growth rate: 39.25 %
# # Infected (today): 149
# # Infected (projected in 7 days): 1512
# --
# Massachusetts
# % growth rate: 21.76 %
# # Infected (today): 413
# # Infected (projected in 7 days): 1638
# --
# Michigan
# % growth rate: 65.27 %
# # Infected (today): 552
# # Infected (projected in 7 days): 18590
# --
# New Jersey
# % growth rate: 61.96 %
# # Infected (today): 890
# # Infected (projected in 7 days): 26018
# --
# New York
# % growth rate: 73.15 %
# # Infected (today): 8310
# # Infected (projected in 7 days): 387729
# --
# North Carolina
# % growth rate: 39.84 %
# # Infected (today): 172
# # Infected (projected in 7 days): 1798
# --
# Ohio
# % growth rate: 45.38 %
# # Infected (today): 173
# # Infected (projected in 7 days): 2374
# --
# Pennsylvania
# % growth rate: 39.44 %
# # Infected (today): 303
# # Infected (projected in 7 days): 3106
# --
# Tennessee
# % growth rate: 51.3 %
# # Infected (today): 233
# # Infected (projected in 7 days): 4228
# --
# Texas
# % growth rate: 53.03 %
# # Infected (today): 394
# # Infected (projected in 7 days): 7744
# --
# Washington
# % growth rate: 14.93 %
# # Infected (today): 1524
# # Infected (projected in 7 days): 4036
# --
# Wisconsin
# % growth rate: 30.19 %
# # Infected (today): 207
# # Infected (projected in 7 days): 1312
# --

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for c in data.keys():
    growth_rate = data[c].rolling(window=3).mean().pct_change() * 100.
    growth_rate.plot(marker='o')

axes.legend()
axes.yaxis.set_major_formatter(mtick.PercentFormatter())
axes.set_title("Growth rate of COVID-19 in " + title_name + "\n (3-day moving average applied to smooth curve)")
axes.set_xlabel("Days after infecting at least "+str(min_case_num)+" people")
# Out:
# Text(0.5, 0, 'Days after infecting at least 100 people')
