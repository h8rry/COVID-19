# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

import glob

# %%
df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv', \
                 parse_dates=True)

# %%
df = df[df['Country/Region'] == 'US']

# %%
df = df[df['Province/State'] != 'Diamond Princess']
df = df[df['Province/State'] != 'Grand Princess']

# %%
df = df.groupby('Province/State').sum()

# %%
df
# Out:
#                            Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Province/State
# Adams, IN              39.8522  -77.2865        0        0        0        0
# Alabama                32.3182  -86.9023        0        0        0        0
# Alachua, FL            29.7938  -82.4944        0        0        0        0
# Alameda County, CA     37.6017 -121.7195        0        0        0        0
# Alaska                 61.3707 -152.4044        0        0        0        0
# ...                        ...       ...      ...      ...      ...      ...
# Williamson County, TN  35.9179  -86.8622        0        0        0        0
# Wisconsin              44.2685  -89.6165        0        0        0        0
# Worcester, MA          42.4097  -71.8571        0        0        0        0
# Wyoming                42.7560 -107.3025        0        0        0        0
# Yolo County, CA        38.7646 -121.9018        0        0        0        0
#
#                        1/26/20  1/27/20  1/28/20  1/29/20  ...  3/8/20  \
# Province/State                                             ...
# Adams, IN                    0        0        0        0  ...       0
# Alabama                      0        0        0        0  ...       0
# Alachua, FL                  0        0        0        0  ...       0
# Alameda County, CA           0        0        0        0  ...       2
# Alaska                       0        0        0        0  ...       0
# ...                        ...      ...      ...      ...  ...     ...
# Williamson County, TN        0        0        0        0  ...       1
# Wisconsin                    0        0        0        0  ...       0
# Worcester, MA                0        0        0        0  ...       0
# Wyoming                      0        0        0        0  ...       0
# Yolo County, CA              0        0        0        0  ...       1
#
#                        3/9/20  3/10/20  3/11/20  3/12/20  3/13/20  3/14/20  \
# Province/State
# Adams, IN                   0        0        0        0        0        0
# Alabama                     0        0        0        0        5        6
# Alachua, FL                 0        0        0        0        0        0
# Alameda County, CA          2        0        0        0        0        0
# Alaska                      0        0        0        0        1        1
# ...                       ...      ...      ...      ...      ...      ...
# Williamson County, TN       1        0        0        0        0        0
# Wisconsin                   0        3        6        8       19       27
# Worcester, MA               0        0        0        0        0        0
# Wyoming                     0        0        0        1        1        2
# Yolo County, CA             1        0        0        0        0        0
#
#                        3/15/20  3/16/20  3/17/20
# Province/State
# Adams, IN                    0        0        0
# Alabama                     12       29       39
# Alachua, FL                  0        0        0
# Alameda County, CA           0        0        0
# Alaska                       1        1        3
# ...                        ...      ...      ...
# Williamson County, TN        0        0        0
# Wisconsin                   32       47       72
# Worcester, MA                0        0        0
# Wyoming                      3        3       11
# Yolo County, CA              0        0        0
#
# [245 rows x 58 columns]

# %%
df = df.T
df = df.drop('Lat')
df = df.drop('Long')

# %%
df.columns
# Out:
# Index(['Adams, IN', 'Alabama', 'Alachua, FL', 'Alameda County, CA', 'Alaska',
#        'Anoka, MN', 'Arapahoe, CO', 'Arizona', 'Arkansas', 'Arlington, VA',
#        ...
#        'Wayne, MI', 'Weber, UT', 'West Virginia', 'Westchester County, NY',
#        'Whatcom, WA', 'Williamson County, TN', 'Wisconsin', 'Worcester, MA',
#        'Wyoming', 'Yolo County, CA'],
#       dtype='object', name='Province/State', length=245)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index.name = 'Date'

# %%
today = df.iloc[-1]

# %%
condition = today[(today >= 100)].index

# %%
print(condition)
# Out:
# Index(['California', 'Colorado', 'Florida', 'Georgia', 'Illinois', 'Louisiana',
#        'Massachusetts', 'New Jersey', 'New York', 'Pennsylvania', 'Texas',
#        'Washington'],
#       dtype='object', name='Province/State')

# %%
min_case_num = 100
title_name = "USA"

# %%
data = {}
data_original = {}

for s in condition:
    state = df[s]
    state0 = state[state > min_case_num]
    
    state0 = state0.reset_index()
    state0 = state0[s]
    
    data[s] = state0
    data_original[s] = df[s]

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data[s].plot(logy=True)

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data[s].plot()

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data_original[s].plot(logy=True)

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data_original[s].plot()

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
today.sum()
# Out:
# 6353.0

# %%
for c in data.keys():
    growth_rate = data[c].tail(5).pct_change().mean()
    num_cases = data[c].iloc[-1]
    projected_num_cases = int(num_cases*(1+growth_rate)**7)
    
    print(c)
    print('% growth rate:', round(growth_rate * 100, 2),'%')
    print('# Infected (today):', int(num_cases))
    print('# Infected (projected in 7 days):', int(projected_num_cases))
    print('--')
# Out:
# California
# % growth rate: 25.48 %
# # Infected (today): 698
# # Infected (projected in 7 days): 3419
# --
# Colorado
# % growth rate: 17.28 %
# # Infected (today): 160
# # Infected (projected in 7 days): 488
# --
# Florida
# % growth rate: 37.07 %
# # Infected (today): 216
# # Infected (projected in 7 days): 1963
# --
# Georgia
# % growth rate: 20.66 %
# # Infected (today): 146
# # Infected (projected in 7 days): 543
# --
# Illinois
# % growth rate: 53.33 %
# # Infected (today): 161
# # Infected (projected in 7 days): 3208
# --
# Louisiana
# % growth rate: 44.12 %
# # Infected (today): 196
# # Infected (projected in 7 days): 2530
# --
# Massachusetts
# % growth rate: 15.45 %
# # Infected (today): 218
# # Infected (projected in 7 days): 596
# --
# New Jersey
# % growth rate: 50.0 %
# # Infected (today): 267
# # Infected (projected in 7 days): 4561
# --
# New York
# % growth rate: 43.16 %
# # Infected (today): 1706
# # Infected (projected in 7 days): 21029
# --
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-62936455ff3d> in <module>
#       3     growth_rate = data[c].tail(5).pct_change().mean()
#       4     num_cases = data[c].iloc[-1]
# ----> 5     projected_num_cases = int(num_cases*(1+growth_rate)**7)
#       6
#       7     print(c)
#
# ValueError: cannot convert float NaN to integer
