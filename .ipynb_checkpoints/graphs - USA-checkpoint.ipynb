# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

import matplotlib.ticker as mtick

import glob

# %%
from census import Census
from us import states

# %%
states.lookup('DC')
# Out:
# <State:District of Columbia>

# %%
df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv', \
                 parse_dates=True)

# %%
df = df[df['Country/Region'] == 'US']

# %%
df = df[df['Province/State'] != 'Diamond Princess']
df = df[df['Province/State'] != 'Grand Princess']

# %%
df = df.groupby('Province/State').sum()

# %%
df
# Out:
#                            Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Province/State
# Adams, IN              39.8522  -77.2865        0        0        0        0
# Alabama                32.3182  -86.9023        0        0        0        0
# Alachua, FL            29.7938  -82.4944        0        0        0        0
# Alameda County, CA     37.6017 -121.7195        0        0        0        0
# Alaska                 61.3707 -152.4044        0        0        0        0
# ...                        ...       ...      ...      ...      ...      ...
# Williamson County, TN  35.9179  -86.8622        0        0        0        0
# Wisconsin              44.2685  -89.6165        0        0        0        0
# Worcester, MA          42.4097  -71.8571        0        0        0        0
# Wyoming                42.7560 -107.3025        0        0        0        0
# Yolo County, CA        38.7646 -121.9018        0        0        0        0
#
#                        1/26/20  1/27/20  1/28/20  1/29/20  ...  3/14/20  \
# Province/State                                             ...
# Adams, IN                    0        0        0        0  ...        0
# Alabama                      0        0        0        0  ...        6
# Alachua, FL                  0        0        0        0  ...        0
# Alameda County, CA           0        0        0        0  ...        0
# Alaska                       0        0        0        0  ...        1
# ...                        ...      ...      ...      ...  ...      ...
# Williamson County, TN        0        0        0        0  ...        0
# Wisconsin                    0        0        0        0  ...       27
# Worcester, MA                0        0        0        0  ...        0
# Wyoming                      0        0        0        0  ...        2
# Yolo County, CA              0        0        0        0  ...        0
#
#                        3/15/20  3/16/20  3/17/20  3/18/20  3/19/20  3/20/20  \
# Province/State
# Adams, IN                    0        0        0        0        0        0
# Alabama                     12       29       39       46       78       83
# Alachua, FL                  0        0        0        0        0        0
# Alameda County, CA           0        0        0        0        0        0
# Alaska                       1        1        3        6        9       12
# ...                        ...      ...      ...      ...      ...      ...
# Williamson County, TN        0        0        0        0        0        0
# Wisconsin                   32       47       72       92      159      207
# Worcester, MA                0        0        0        0        0        0
# Wyoming                      3        3       11       15       18       19
# Yolo County, CA              0        0        0        0        0        0
#
#                        3/21/20  3/22/20  3/23/20
# Province/State
# Adams, IN                    0        0      0.0
# Alabama                    131      138    138.0
# Alachua, FL                  0        0      0.0
# Alameda County, CA           0        0      0.0
# Alaska                      15       21     21.0
# ...                        ...      ...      ...
# Williamson County, TN        0        0      0.0
# Wisconsin                  282      381    381.0
# Worcester, MA                0        0      0.0
# Wyoming                     23       24     24.0
# Yolo County, CA              0        0      0.0
#
# [247 rows x 64 columns]

# %%
df = df.T
df = df.drop('Lat')
df = df.drop('Long')

# %%
df.columns
# Out:
# Index(['Adams, IN', 'Alabama', 'Alachua, FL', 'Alameda County, CA', 'Alaska',
#        'Anoka, MN', 'Arapahoe, CO', 'Arizona', 'Arkansas', 'Arlington, VA',
#        ...
#        'Wayne, MI', 'Weber, UT', 'West Virginia', 'Westchester County, NY',
#        'Whatcom, WA', 'Williamson County, TN', 'Wisconsin', 'Worcester, MA',
#        'Wyoming', 'Yolo County, CA'],
#       dtype='object', name='Province/State', length=247)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index.name = 'Date'

# %%
today = df.iloc[-1]

# %%
condition = today[(today > 250)].index

# %%
print(condition)
# Out:
# Index(['California', 'Colorado', 'Florida', 'Georgia', 'Illinois', 'Louisiana',
#        'Massachusetts', 'Michigan', 'New Jersey', 'New York', 'North Carolina',
#        'Ohio', 'Pennsylvania', 'Tennessee', 'Texas', 'Washington',
#        'Wisconsin'],
#       dtype='object', name='Province/State')

# %%
min_case_num = 250
title_name = "USA"

# %%
data = {}
data_original = {}

for s in condition:
    state = df[s]
    state0 = state[state > min_case_num]
    
    state0 = state0.reset_index()
    state0 = state0[s]
    
    data[s] = state0
    data_original[s] = df[s]

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 250 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 250 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
today.sum()
# Out:
# 33197.0

# %%
for c in data.keys():
    if len(data[c]) > 1:
        growth_rate = data[c].tail(5).pct_change().mean()
        num_cases = data[c].iloc[-1]
        projected_num_cases = int(num_cases*(1+growth_rate)**7)

        print(c)
        print('% growth rate:', round(growth_rate * 100, 2),'%')
        print('# Infected (today):', int(num_cases))
        print('# Infected (projected in 7 days):', int(projected_num_cases))
        print('--')
# Out:
# California
# % growth rate: 14.98 %
# # Infected (today): 1642
# # Infected (projected in 7 days): 4361
# --
# Colorado
# % growth rate: 15.13 %
# # Infected (today): 476
# # Infected (projected in 7 days): 1276
# --
# Florida
# % growth rate: 19.5 %
# # Infected (today): 830
# # Infected (projected in 7 days): 2888
# --
# Georgia
# % growth rate: 21.35 %
# # Infected (today): 600
# # Infected (projected in 7 days): 2325
# --
# Illinois
# % growth rate: 26.66 %
# # Infected (today): 1049
# # Infected (projected in 7 days): 5486
# --
# Louisiana
# % growth rate: 22.26 %
# # Infected (today): 837
# # Infected (projected in 7 days): 3418
# --
# Massachusetts
# % growth rate: 19.02 %
# # Infected (today): 646
# # Infected (projected in 7 days): 2185
# --
# Michigan
# % growth rate: 34.91 %
# # Infected (today): 1037
# # Infected (projected in 7 days): 8433
# --
# New Jersey
# % growth rate: 28.32 %
# # Infected (today): 1914
# # Infected (projected in 7 days): 10965
# --
# New York
# % growth rate: 32.67 %
# # Infected (today): 15793
# # Infected (projected in 7 days): 114247
# --
# North Carolina
# % growth rate: 9.68 %
# # Infected (today): 302
# # Infected (projected in 7 days): 576
# --
# Ohio
# % growth rate: 0.0 %
# # Infected (today): 355
# # Infected (projected in 7 days): 355
# --
# Pennsylvania
# % growth rate: 19.74 %
# # Infected (today): 509
# # Infected (projected in 7 days): 1796
# --
# Tennessee
# % growth rate: 18.06 %
# # Infected (today): 505
# # Infected (projected in 7 days): 1614
# --
# Texas
# % growth rate: 26.73 %
# # Infected (today): 627
# # Infected (projected in 7 days): 3291
# --
# Washington
# % growth rate: 9.93 %
# # Infected (today): 1996
# # Infected (projected in 7 days): 3872
# --
# Wisconsin
# % growth rate: 17.55 %
# # Infected (today): 381
# # Infected (projected in 7 days): 1181
# --

# %%
fig, axes = plt.subplots(len(data.keys()), figsize=(10, 20))

i = 0
for c in data.keys():
    data[c].diff().plot(ax=axes[i], kind="bar")
    axes[i].legend()
    i += 1

axes[0].set_title("# of NEW confirmed COVID-19 cases in " + title_name)
axes[-1].set_xlabel("Days after passing " + str(min_case_num) + " confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 250 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for c in data.keys():
    growth_rate = data[c].rolling(window=3).mean().pct_change() * 100.
    growth_rate.plot(marker='o')

axes.legend()
axes.yaxis.set_major_formatter(mtick.PercentFormatter())
axes.set_title("Growth rate of COVID-19 in " + title_name + "\n (3-day moving average applied to smooth curve)")
axes.set_xlabel("Days after infecting at least "+str(min_case_num)+" people")
# Out:
# Text(0.5, 0, 'Days after infecting at least 250 people')
