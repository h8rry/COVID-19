# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

import matplotlib.ticker as mtick

import glob

# %%
from census import Census
from us import states

# %%
states.lookup('DC')
# Out:
# <State:District of Columbia>

# %%
df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv', \
                 parse_dates=True)

# %%
# df

# %%
# df = df[df['Country/Region'] == 'US']

# %%
df = df[df['Province_State'] != 'Diamond Princess']
df = df[df['Province_State'] != 'Grand Princess']

# %%
df = df.groupby('Province_State').sum()

# %%
# df

# %%
# df.columns
# Out:
# Index(['UID', 'code3', 'FIPS', 'Lat', 'Long_', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20',
#        '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20',
#        '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20',
#        '3/28/20', '3/29/20'],
#       dtype='object')

# %%
df = df.T
df = df.drop('Lat')
df = df.drop('Long_')
df = df.drop('UID')
df = df.drop('code3')
df = df.drop('FIPS')

# %%
# df.columns
# Out:
# Index(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Guam', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Northern Mariana Islands', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Recovered',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas',
#        'Utah', 'Vermont', 'Virgin Islands', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='Province_State')

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index.name = 'Date'

# %%
today = df.iloc[-1]

# %%
condition = today[(today > 250)].index

# %%
print(condition)
# Out:
# Index(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'District of Columbia', 'Florida', 'Georgia', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Nevada', 'New Jersey', 'New York',
#        'North Carolina', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Recovered', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas',
#        'Utah', 'Virginia', 'Washington', 'Wisconsin'],
#       dtype='object', name='Province_State')

# %%
min_case_num = 250
title_name = "USA"

# %%
data = {}
data_original = {}

for s in condition:
    state = df[s]
    state0 = state[state > min_case_num]
    
    state0 = state0.reset_index()
    state0 = state0[s]
    
    data[s] = state0
    data_original[s] = df[s]

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 250 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Days after passing "+str(min_case_num)+" confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 250 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(logy=True, marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Log Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for s in data.keys():
    data_original[s].plot(marker='o')

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in "+title_name+" (Linear Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
today.sum()
# Out:
# 143407.0

# %%
for c in data.keys():
    if len(data[c]) > 1:
        growth_rate = data[c].tail(5).pct_change().mean()
        num_cases = data[c].iloc[-1]
        projected_num_cases = int(num_cases*(1+growth_rate)**7)

        print(c)
        print('% growth rate:', round(growth_rate * 100, 2),'%')
        print('# Infected (today):', int(num_cases))
        print('# Infected (projected in 7 days):', int(projected_num_cases))
        print('--')
# Out:
# Alabama
# % growth rate: 21.58 %
# # Infected (today): 825
# # Infected (projected in 7 days): 3240
# --
# Arizona
# % growth rate: 23.18 %
# # Infected (today): 919
# # Infected (projected in 7 days): 3954
# --
# Arkansas
# % growth rate: 11.22 %
# # Infected (today): 426
# # Infected (projected in 7 days): 896
# --
# California
# % growth rate: 18.44 %
# # Infected (today): 5852
# # Infected (projected in 7 days): 19132
# --
# Colorado
# % growth rate: 23.57 %
# # Infected (today): 2307
# # Infected (projected in 7 days): 10149
# --
# Connecticut
# % growth rate: 23.01 %
# # Infected (today): 1993
# # Infected (projected in 7 days): 8494
# --
# District of Columbia
# % growth rate: 12.34 %
# # Infected (today): 342
# # Infected (projected in 7 days): 772
# --
# Florida
# % growth rate: 26.44 %
# # Infected (today): 4246
# # Infected (projected in 7 days): 21937
# --
# Georgia
# % growth rate: 20.95 %
# # Infected (today): 2651
# # Infected (projected in 7 days): 10036
# --
# Illinois
# % growth rate: 25.58 %
# # Infected (today): 4596
# # Infected (projected in 7 days): 22640
# --
# Indiana
# % growth rate: 33.91 %
# # Infected (today): 1513
# # Infected (projected in 7 days): 11684
# --
# Iowa
# % growth rate: 12.75 %
# # Infected (today): 336
# # Infected (projected in 7 days): 778
# --
# Kansas
# % growth rate: 24.06 %
# # Infected (today): 330
# # Infected (projected in 7 days): 1492
# --
# Kentucky
# % growth rate: 21.01 %
# # Infected (today): 438
# # Infected (projected in 7 days): 1664
# --
# Louisiana
# % growth rate: 18.76 %
# # Infected (today): 3540
# # Infected (projected in 7 days): 11796
# --
# Maryland
# % growth rate: 30.75 %
# # Infected (today): 1239
# # Infected (projected in 7 days): 8096
# --
# Massachusetts
# % growth rate: 28.33 %
# # Infected (today): 4963
# # Infected (projected in 7 days): 28454
# --
# Michigan
# % growth rate: 24.41 %
# # Infected (today): 5488
# # Infected (projected in 7 days): 25310
# --
# Minnesota
# % growth rate: 15.2 %
# # Infected (today): 503
# # Infected (projected in 7 days): 1354
# --
# Mississippi
# % growth rate: 19.25 %
# # Infected (today): 759
# # Infected (projected in 7 days): 2603
# --
# Missouri
# % growth rate: 27.49 %
# # Infected (today): 915
# # Infected (projected in 7 days): 5007
# --
# Nevada
# % growth rate: 30.35 %
# # Infected (today): 920
# # Infected (projected in 7 days): 5883
# --
# New Jersey
# % growth rate: 32.73 %
# # Infected (today): 13386
# # Infected (projected in 7 days): 97163
# --
# New York
# % growth rate: 17.97 %
# # Infected (today): 59648
# # Infected (projected in 7 days): 189699
# --
# North Carolina
# % growth rate: 19.26 %
# # Infected (today): 1191
# # Infected (projected in 7 days): 4086
# --
# Ohio
# % growth rate: 23.88 %
# # Infected (today): 1653
# # Infected (projected in 7 days): 7400
# --
# Oklahoma
# % growth rate: 15.44 %
# # Infected (today): 429
# # Infected (projected in 7 days): 1171
# --
# Oregon
# % growth rate: 20.0 %
# # Infected (today): 548
# # Infected (projected in 7 days): 1963
# --
# Pennsylvania
# % growth rate: 28.76 %
# # Infected (today): 3432
# # Infected (projected in 7 days): 20142
# --
# Recovered
# % growth rate: 72.05 %
# # Infected (today): 2665
# # Infected (projected in 7 days): 118939
# --
# South Carolina
# % growth rate: 16.72 %
# # Infected (today): 774
# # Infected (projected in 7 days): 2284
# --
# Tennessee
# % growth rate: 17.1 %
# # Infected (today): 1720
# # Infected (projected in 7 days): 5191
# --
# Texas
# % growth rate: 22.89 %
# # Infected (today): 2792
# # Infected (projected in 7 days): 11820
# --
# Utah
# % growth rate: 20.7 %
# # Infected (today): 720
# # Infected (projected in 7 days): 2687
# --
# Virginia
# % growth rate: 22.53 %
# # Infected (today): 890
# # Infected (projected in 7 days): 3690
# --
# Washington
# % growth rate: 14.72 %
# # Infected (today): 4465
# # Infected (projected in 7 days): 11678
# --
# Wisconsin
# % growth rate: 17.17 %
# # Infected (today): 1164
# # Infected (projected in 7 days): 3529
# --

# %%
fig, axes = plt.subplots(len(data.keys()), figsize=(10, 20))

i = 0
for c in data.keys():
    data[c].diff().plot(ax=axes[i], kind="bar")
    axes[i].legend()
    i += 1

axes[0].set_title("# of NEW confirmed COVID-19 cases in " + title_name)
axes[-1].set_xlabel("Days after passing " + str(min_case_num) + " confirmed cases")

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(10, 10))

for c in data.keys():
    growth_rate = data[c].rolling(window=3).mean().pct_change() * 100.
    growth_rate.plot(marker='o')

axes.legend()
axes.yaxis.set_major_formatter(mtick.PercentFormatter())
axes.set_title("Growth rate of COVID-19 in " + title_name + "\n (3-day moving average applied to smooth curve)")
axes.set_xlabel("Days after infecting at least "+str(min_case_num)+" people")
