# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

import glob

# %%
df = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv', \
                 parse_dates=True)

# %%
df = df[df['Country/Region'] == 'China']

# %%
df = df[df['Province/State'] != 'Diamond Princess']

# %%
df = df.groupby('Province/State').sum()

# %%
df
# Out:
#                     Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Province/State
# Anhui           31.8257  117.2264        1        9       15       39
# Beijing         40.1824  116.4142       14       22       36       41
# Chongqing       30.0572  107.8740        6        9       27       57
# Fujian          26.0789  117.9874        1        5       10       18
# Gansu           37.8099  101.0583        0        2        2        4
# Guangdong       23.3417  113.4244       26       32       53       78
# Guangxi         23.8298  108.7881        2        5       23       23
# Guizhou         26.8154  106.8748        1        3        3        4
# Hainan          19.1959  109.7453        4        5        8       19
# Hebei           39.5490  116.1306        1        1        2        8
# Heilongjiang    47.8620  127.7615        0        2        4        9
# Henan           33.8820  113.6140        5        5        9       32
# Hong Kong       22.3000  114.2000        0        2        2        5
# Hubei           30.9756  112.2707      444      444      549      761
# Hunan           27.6104  111.7088        4        9       24       43
# Inner Mongolia  44.0935  113.9448        0        0        1        7
# Jiangsu         32.9711  119.4550        1        5        9       18
# Jiangxi         27.6140  115.7221        2        7       18       18
# Jilin           43.6661  126.1923        0        1        3        4
# Liaoning        41.2956  122.6085        2        3        4       17
# Macau           22.1667  113.5500        1        2        2        2
# Ningxia         37.2692  106.1655        1        1        2        3
# Qinghai         35.7452   95.9956        0        0        0        1
# Shaanxi         35.1917  108.8701        0        3        5       15
# Shandong        36.3427  118.1498        2        6       15       27
# Shanghai        31.2020  121.4491        9       16       20       33
# Shanxi          37.5777  112.2922        1        1        1        6
# Sichuan         30.6171  102.7103        5        8       15       28
# Tianjin         39.3054  117.3230        4        4        8       10
# Tibet           31.6927   88.0924        0        0        0        0
# Xinjiang        41.1129   85.2401        0        2        2        3
# Yunnan          24.9740  101.4870        1        2        5       11
# Zhejiang        29.1832  120.0934       10       27       43       62
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  3/4/20  3/5/20  \
# Province/State                                      ...
# Anhui                60       70      106      152  ...     990     990
# Beijing              68       80       91      111  ...     418     418
# Chongqing            75      110      132      147  ...     576     576
# Fujian               35       59       80       84  ...     296     296
# Gansu                 7       14       19       24  ...      91     102
# Guangdong           111      151      207      277  ...    1350    1351
# Guangxi              36       46       51       58  ...     252     252
# Guizhou               5        7        9        9  ...     146     146
# Hainan               22       33       40       43  ...     168     168
# Hebei                13       18       33       48  ...     318     318
# Heilongjiang         15       21       33       38  ...     480     481
# Henan                83      128      168      206  ...    1272    1272
# Hong Kong             8        8        8       10  ...     105     105
# Hubei              1058     1423     3554     3554  ...   67332   67466
# Hunan                69      100      143      221  ...    1018    1018
# Inner Mongolia        7       11       15       16  ...      75      75
# Jiangsu              33       47       70       99  ...     631     631
# Jiangxi              36       72      109      109  ...     935     935
# Jilin                 4        6        8        9  ...      93      93
# Liaoning             21       27       34       39  ...     125     125
# Macau                 5        6        7        7  ...      10      10
# Ningxia               4        7       11       12  ...      75      75
# Qinghai               1        6        6        6  ...      18      18
# Shaanxi              22       35       46       56  ...     245     245
# Shandong             46       75       95      130  ...     758     758
# Shanghai             40       53       66       96  ...     338     339
# Shanxi                9       13       27       27  ...     133     133
# Sichuan              44       69       90      108  ...     538     539
# Tianjin              14       23       24       27  ...     136     136
# Tibet                 0        0        0        0  ...       1       1
# Xinjiang              4        5       10       13  ...      76      76
# Yunnan               16       26       44       55  ...     174     174
# Zhejiang            104      128      173      296  ...    1213    1215
#
#                 3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20  3/12/20  \
# Province/State
# Anhui              990     990     990     990      990      990      990
# Beijing            422     426     428     428      429      435      435
# Chongqing          576     576     576     576      576      576      576
# Fujian             296     296     296     296      296      296      296
# Gansu              119     120     124     124      125      127      127
# Guangdong         1352    1352    1352    1352     1353     1356     1356
# Guangxi            252     252     252     252      252      252      252
# Guizhou            146     146     146     146      146      146      146
# Hainan             168     168     168     168      168      168      168
# Hebei              318     318     318     318      318      318      318
# Heilongjiang       481     481     481     481      481      482      482
# Henan             1272    1272    1272    1272     1272     1273     1273
# Hong Kong          107     108     114     115      120      126      129
# Hubei            67592   67666   67707   67743    67760    67773    67781
# Hunan             1018    1018    1018    1018     1018     1018     1018
# Inner Mongolia      75      75      75      75       75       75       75
# Jiangsu            631     631     631     631      631      631      631
# Jiangxi            935     935     935     935      935      935      935
# Jilin               93      93      93      93       93       93       93
# Liaoning           125     125     125     125      125      125      125
# Macau               10      10      10      10       10       10       10
# Ningxia             75      75      75      75       75       75       75
# Qinghai             18      18      18      18       18       18       18
# Shaanxi            245     245     245     245      245      245      245
# Shandong           758     758     758     758      758      760      760
# Shanghai           342     342     342     342      344      344      344
# Shanxi             133     133     133     133      133      133      133
# Sichuan            539     539     539     539      539      539      539
# Tianjin            136     136     136     136      136      136      136
# Tibet                1       1       1       1        1        1        1
# Xinjiang            76      76      76      76       76       76       76
# Yunnan             174     174     174     174      174      174      174
# Zhejiang          1215    1215    1215    1215     1215     1215     1215
#
#                 3/13/20
# Province/State
# Anhui               990
# Beijing             436
# Chongqing           576
# Fujian              296
# Gansu               127
# Guangdong          1356
# Guangxi             252
# Guizhou             146
# Hainan              168
# Hebei               318
# Heilongjiang        482
# Henan              1273
# Hong Kong           134
# Hubei             67786
# Hunan              1018
# Inner Mongolia       75
# Jiangsu             631
# Jiangxi             935
# Jilin                93
# Liaoning            125
# Macau                10
# Ningxia              75
# Qinghai              18
# Shaanxi             245
# Shandong            760
# Shanghai            346
# Shanxi              133
# Sichuan             539
# Tianjin             136
# Tibet                 1
# Xinjiang             76
# Yunnan              174
# Zhejiang           1215
#
# [33 rows x 54 columns]

# %%
df = df.T
df = df.drop('Lat')
df = df.drop('Long')

# %%
df.columns
# Out:
# Index(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hong Kong', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi',
#        'Jilin', 'Liaoning', 'Macau', 'Ningxia', 'Qinghai', 'Shaanxi',
#        'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet',
#        'Xinjiang', 'Yunnan', 'Zhejiang'],
#       dtype='object', name='Province/State')

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index.name = 'Date'

# %%
today = df.iloc[-1]

# %%
condition = today[(today >= 500)].index

# %%
print(condition)
# Out:
# Index(['Anhui', 'Chongqing', 'Guangdong', 'Henan', 'Hubei', 'Hunan', 'Jiangsu',
#        'Jiangxi', 'Shandong', 'Sichuan', 'Zhejiang'],
#       dtype='object', name='Province/State')

# %%
data = {}
data_original = {}

for s in condition:
    state = df[s]
    state0 = state[state > 500]
    
    state0 = state0.reset_index()
    state0 = state0[s]
    
    data[s] = state0
    data_original[s] = df[s]

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data[s].plot(logy=True)

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in China (Log Scale)")
axes.set_xlabel("Days after passing 500 confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data[s].plot()

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in China (Linear Scale)")
axes.set_xlabel("Days after passing 500 confirmed cases")
# Out:
# Text(0.5, 0, 'Days after passing 100 confirmed cases')

# %%
fig, axes = plt.subplots(1, sharex="all", gridspec_kw={'height_ratios': [1]}, figsize=(8, 5))

for s in data.keys():
    data_original[s].plot()

axes.legend()
axes.set_title("# of Confirmed COVID-19 cases in China (Linear Scale)")
axes.set_xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %%
today.sum()
# Out:
# 80945.0
